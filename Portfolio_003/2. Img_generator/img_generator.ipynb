# %% [markdown]
# # Pre_processing

# %%
import tensorflow as tf

from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# %% [markdown]
# ## Resize

# %%
## Resize & create file by order:asc

import loader_shoes_func_v2
import os   
    
path_etc = 'C:\\Users\\KJM\\shoes\\##resize_ver2\\vans_v2\\datagen_raw'
path_re = 'C:\\Users\\KJM\\shoes\\##resize_ver2\\vans_v2\\datagen_re_v2'

loader_shoes_func_v2.resize(path_etc, path_re)
# Out:
# img shape (128, 128, 3)

# %% [markdown]
# ## Load X : Features

# %%
## Load X : Features

import loader_shoes

path_re = "C:\\Users\\KJM\\shoes\\##resize_ver2\\vans_v2\\datagen_re_v2"
resize = loader_shoes.image_load(path_re)

# %%
## Check out first img(resized)
import matplotlib.pyplot as plt

img = resize[0, : ]
plt.figure()
plt.imshow(img)

print(resize.shape)
# Out:
# (10, 128, 128, 3)

# %%
## Make X (feature)
X = resize
X.shape
# Out:
# (10, 128, 128, 3)

# %%
X = X.astype('float')
X = X/255
X.shape
# Out:
# (10, 128, 128, 3)

# %%
# 아래의 url 참고
# https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator

preview = 'C:\\Users\\KJM\\shoes\\##resize_ver2\\vans_v2\\vans_datagen' # 증식한 이미지 저장 경로

loader_shoes_func_v2.datagen(preview, X, 500) # (경로, 데이터, 증식 횟수)
